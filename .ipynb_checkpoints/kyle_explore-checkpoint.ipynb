# %%
from trackml.dataset import load_event
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
event = 'event000001000'

hits,cells,particles,truth = load_event('/Users/kylebradley/Downloads/train_1/' + event)

# %%
hits.head()
# Out:
#    hit_id          x         y       z  volume_id  layer_id  module_id
# 0       1 -64.409897 -7.163700 -1502.5          7         2          1
# 1       2 -55.336102  0.635342 -1502.5          7         2          1
# 2       3 -83.830498 -1.143010 -1502.5          7         2          1
# 3       4 -96.109100 -8.241030 -1502.5          7         2          1
# 4       5 -62.673599 -9.371200 -1502.5          7         2          1

# %%
cells.head()
# Out:
#    hit_id  ch0  ch1     value
# 0       1  209  617  0.013832
# 1       1  210  617  0.079887
# 2       1  209  618  0.211723
# 3       2   68  446  0.334087
# 4       3   58  954  0.034005

# %%
particles.head()
# Out:
#         particle_id        vx        vy        vz         px         py  \
# 0  4503668346847232 -0.009288  0.009861 -0.077879  -0.055269   0.323272
# 1  4503737066323968 -0.009288  0.009861 -0.077879  -0.948125   0.470892
# 2  4503805785800704 -0.009288  0.009861 -0.077879  -0.886484   0.105749
# 3  4503874505277440 -0.009288  0.009861 -0.077879   0.257539  -0.676718
# 4  4503943224754176 -0.009288  0.009861 -0.077879  16.439400 -15.548900
#
#           pz  q  nhits
# 0  -0.203492 -1      8
# 1   2.010060  1     11
# 2   0.683881 -1      0
# 3   0.991616  1     12
# 4 -39.824902  1      3

# %%
truth.head()
# Out:
#    hit_id         particle_id         tx        ty      tz            tpx  \
# 0       1                   0 -64.411598 -7.164120 -1502.5  250710.000000
# 1       2   22525763437723648 -55.338501  0.630805 -1502.5      -0.570605
# 2       3                   0 -83.828003 -1.145580 -1502.5  626295.000000
# 3       4  297237712845406208 -96.122902 -8.230360 -1502.5      -0.225235
# 4       5  418835796137607168 -62.659401 -9.375040 -1502.5      -0.281806
#
#              tpy           tpz    weight
# 0 -149908.000000 -956385.00000  0.000000
# 1       0.028390     -15.49220  0.000010
# 2 -169767.000000 -760877.00000  0.000000
# 3      -0.050968      -3.70232  0.000008
# 4      -0.023487      -6.57318  0.000009

# %%
plt.figure(figsize=(10,10))
volumes = hits.volume_id.unique()
for vol in volumes:
    v = hits[hits.volume_id == vol]
    plt.scatter(v.x,v.y, s=1, label = 'volume {}'.format(vol))
plt.legend()
plt.show()

# %%
lst = particles.particle_id[particles.nhits ==10]
lst =lst.values

# %%
len(lst)
# Out:
# 1037

# %%
hit_part = truth[truth.particle_id == part]

# %%
hit_part
# Out:
#        hit_id       particle_id          tx          ty          tz       tpx  \
# 20340   20341  4517893278531584   28.860001   14.215200  -59.826099  0.195995
# 20485   20486  4517893278531584   29.704901   14.681500  -61.614201  0.196337
# 28094   28095  4517893278531584   62.402100   35.021599 -132.848999  0.183079
# 34430   34431  4517893278531584   97.125099   62.252300 -214.223007  0.167254
# 40806   40807  4517893278531584  136.462997  103.600998 -319.871002  0.140930
# 40812   40813  4517893278531584  137.634995  105.047997 -323.308990  0.139274
#
#             tpy       tpz    weight
# 20340  0.107842 -0.414472  0.000024
# 20485  0.108806 -0.414021  0.000016
# 28094  0.127358 -0.413905  0.000011
# 34430  0.149100 -0.412489  0.000007
# 40806  0.173016 -0.412137  0.000009
# 40812  0.174508 -0.412028  0.000014

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# <img src="data:image/png;base64,..." width="160">
# Text(0.5,0,'Z')

# %%
for ind in range(0,30):
    hit_part = truth[truth.particle_id == lst[ind]]
    ax.plot(hit_part.tx,hit_part.ty, hit_part.tz, '.-')

# %%
plt.savefig('3d movement plot')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
x = hits.x.values
y = hits.y.values
z = hits.z.values

# %%
r = np.sqrt(x**2+ y**2+z**2)

# %%
hits['x2'] = x/r
hits['y2'] = y/r

# %%
r2 = np.sqrt(x**2+y**2)
hits['z2'] = z/r

# %%
hits.head()
# Out:
#    hit_id          x         y       z  volume_id  layer_id  module_id  \
# 0       1 -64.409897 -7.163700 -1502.5          7         2          1
# 1       2 -55.336102  0.635342 -1502.5          7         2          1
# 2       3 -83.830498 -1.143010 -1502.5          7         2          1
# 3       4 -96.109100 -8.241030 -1502.5          7         2          1
# 4       5 -62.673599 -9.371200 -1502.5          7         2          1
#
#          x2        y2        z2
# 0 -0.042829 -0.004763 -0.999071
# 1 -0.036804  0.000423 -0.999322
# 2 -0.055707 -0.000760 -0.998447
# 3 -0.063835 -0.005474 -0.997945
# 4 -0.041676 -0.006232 -0.999112

# %%
ss = StandardScaler()
X = ss.fit_transform(hits[['x2','y2','z2']].values)

model = DBSCAN(eps = .008)

# %%
labels = model.fit_predict(X)

# %%
labels
# Out:
# array([ 0,  0, -1, ..., -1, -1, -1])

# %%
labels.mean()
# Out:
# 192.21271880865561
